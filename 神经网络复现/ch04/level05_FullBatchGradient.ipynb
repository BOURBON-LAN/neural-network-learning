# %%
from HelperClass.NeuralNet_1_0 import *

file_name = "ch04.npz"

if __name__ == '__main__':
    sdr = DataReader_1_0(file_name)
    sdr.ReadData()
    hp = HyperParameters_1_0(1, 1, eta=0.5, max_epoch=1000, batch_size=-1, eps = 0.02)
    net = NeuralNet_1_0(hp)
    net.train(sdr)
# Out:
# epoch=0
# 0 0 1.154357909006821
# epoch=1
# 1 0 0.17979033756465618
# epoch=2
# 2 0 0.0441505853617878
# epoch=3
# 3 0 0.025126287387083623
# epoch=4
# 4 0 0.022320574907747037
# epoch=5
# 5 0 0.021778430954880825
# epoch=6
# 6 0 0.021559671993035056
# epoch=7
# 7 0 0.02139412147482112
# epoch=8
# 8 0 0.021243750991158352
# epoch=9
# 9 0 0.02110282647424009
# epoch=10
# 10 0 0.020970128366949267
# epoch=11
# 11 0 0.020845088936904142
# epoch=12
# 12 0 0.02072725398866659
# epoch=13
# 13 0 0.020616206724334032
# epoch=14
# 14 0 0.020511555915564417
# epoch=15
# 15 0 0.02041293308615266
# epoch=16
# 16 0 0.020319991014599505
# epoch=17
# 17 0 0.020232402483846418
# epoch=18
# 18 0 0.020149859125392678
# epoch=19
# 19 0 0.02007207033310096
# epoch=20
# 20 0 0.019998762240000554
# [[1.81701209]] [[3.11615436]]
